# %%
#Some of these libraries are likely not necessary. Have not yet tested to determine which. Likely most of the dask libraries are unnecessary because we are only using a single GPU.
import time
import pandas as pd
import numpy as np
import scanpy as sc
import anndata
import pickle
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from natsort import natsorted

import better_rapids_leiden as brl

import cupy as cp
import cupyx as cpx
import cupyx
import cugraph

import cudf
import math

import h5py
import scipy

import dask
import dask_cudf
import rmm

from dask_cuda import initialize, LocalCUDACluster
from dask import delayed, dataframe
from dask.dataframe.utils import make_meta
from dask.distributed import Client, default_client
from dask_cuda.local_cuda_cluster import cuda_visible_devices
import dask.dataframe as dd

from cuml.manifold import TSNE, UMAP
from cuml.linear_model import LinearRegression

from sklearn.decomposition import PCA
from cuml.dask.cluster import KMeans as cu_dask_KMeans
from cuml.dask.manifold import UMAP as cu_dask_UMAP
from cuml.dask.linear_model import LinearRegression as cu_dask_LinearRegression
from cuml.dask.neighbors import NearestNeighbors as cu_dask_NearestNeighbors

#Better Rapids Leiden import
import better_rapids_leiden as brl

#These need to present as .py files in the directory.
import rapids_scanpy_funcs as rsc
import utils as utils

#I'm not actually sure what this does, but I was told to include it by the RAPIDS manual.
import warnings
warnings.filterwarnings('ignore', 'Expected ')
warnings.simplefilter('ignore')

#This lets you oversubscribe memory on the GPU.
rmm.reinitialize(managed_memory=False)
cp.cuda.set_allocator(rmm.rmm_cupy_allocator)

# %%
#Read in anndata as a pickle file from previous script.
with open('adata_pickle', 'rb') as f:
    adata = pickle.load(f)

# %%
new_adata_path = "/scratch/avannan/late_IPF_spatial/xenium/REVISION_rds_files/MYELOID_xenium_final_CT_plus_niches_RAPIDS_clustered_071624.h5ad"
new_metadata_path = "/scratch/avannan/temp_metadata.csv"

# %%
#Storing raw counts separately.
adata.raw = adata

# %%
sc.pp.log1p(adata)

# %%
sc.pp.scale(adata)

# %%
#Run PCA.
sc.tl.pca(adata, n_comps=20)

# %% [raw]
# # Optional: Harmony integration
# import scanpy.external as sce
# sce.pp.harmony_integrate(adata, "tma")
# sc.pp.neighbors(adata, use_rep='X_pca_harmony', n_neighbors=20, n_pcs=20, method='rapids')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 336312 × 343
# ...

# %%
#Find neighbours. Make sure method is set to rapids or it won't run on the GPU.
sc.pp.neighbors(adata, use_rep='X_pca', n_neighbors=20, n_pcs=20, method='rapids')

# %% [raw]
# #Run PCA.
# sc.tl.pca(adata, n_comps=20)
# #Find neighbours. Make sure method is set to rapids or it won't run on the GPU.
# sc.pp.neighbors(adata, use_rep='X_pca', n_neighbors=10, n_pcs=10, method='rapids')

# %%
#Leiden clustering
brl.leiden(adata, key_added="leiden_res0.1", resolution=0.1)
brl.leiden(adata, key_added="leiden_res0.15", resolution=0.15)
brl.leiden(adata, key_added="leiden_res0.2", resolution=0.2)
brl.leiden(adata, key_added="leiden_res0.25", resolution=0.25)
brl.leiden(adata, key_added="leiden_res0.3", resolution=0.3)
brl.leiden(adata, key_added="leiden_res0.4", resolution=0.4)
brl.leiden(adata, key_added="leiden_res0.5", resolution=0.5)
brl.leiden(adata, key_added="leiden_res0.6", resolution=0.6)
brl.leiden(adata, key_added="leiden_res0.7", resolution=0.7)
brl.leiden(adata, key_added="leiden_res0.8", resolution=0.8)

# %%
#Run UMAP. Make sure method is set to rapids or it won't run on the GPU.
sc.tl.umap(adata, random_state=42, method='rapids')
sc.pl.umap(adata, color=["leiden_res0.5", "run", "nCount_RNA"])
#sc.pl.umap(adata, color="CT_firstpass")
# Out:
# WARNING: .obsp["connectivities"] have not been computed using umap

# %%
#Change data type for leiden column to string and to category
adata.obs["leiden_res0.1"] = adata.obs["leiden_res0.1"].astype('str')
adata.obs["leiden_res0.1"] = adata.obs["leiden_res0.1"].astype('category')

adata.obs["leiden_res0.2"] = adata.obs["leiden_res0.2"].astype('str')
adata.obs["leiden_res0.2"] = adata.obs["leiden_res0.2"].astype('category')

adata.obs["leiden_res0.3"] = adata.obs["leiden_res0.3"].astype('str')
adata.obs["leiden_res0.3"] = adata.obs["leiden_res0.3"].astype('category')

adata.obs["leiden_res0.4"] = adata.obs["leiden_res0.4"].astype('str')
adata.obs["leiden_res0.4"] = adata.obs["leiden_res0.4"].astype('category')

adata.obs["leiden_res0.5"] = adata.obs["leiden_res0.5"].astype('str')
adata.obs["leiden_res0.5"] = adata.obs["leiden_res0.5"].astype('category')

adata.obs["leiden_res0.6"] = adata.obs["leiden_res0.6"].astype('str')
adata.obs["leiden_res0.6"] = adata.obs["leiden_res0.6"].astype('category')

adata.obs["leiden_res0.7"] = adata.obs["leiden_res0.7"].astype('str')
adata.obs["leiden_res0.7"] = adata.obs["leiden_res0.7"].astype('category')

adata.obs["leiden_res0.8"] = adata.obs["leiden_res0.8"].astype('str')
adata.obs["leiden_res0.8"] = adata.obs["leiden_res0.8"].astype('category')

# %% [raw]
# #Subclustering - "full_merged_nucleus_nucleus_RAPIDS_clustered_052824.rds"
# #Subcluster proliferating mix
# brl.leiden(adata, key_added="leiden_res0.5_sub3_res0.1", resolution=0.1, restrict_to = ("leiden_res0.5", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub3_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub3_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub3_res0.4", resolution=0.4, restrict_to = ("leiden_res0.5", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub3_res0.5", resolution=0.5, restrict_to = ("leiden_res0.5", ["3"]))
# sc.pl.umap(adata, color='leiden_res0.5_sub3_res0.5')

# %% [raw]
# #Subclustering - "endothelial_lineage_split_nucnuc_RAPIDS_clustered_052824.rds"
# #Subcluster 1 to get peribronchial/venous split
# brl.leiden(adata, key_added="leiden_res0.4_sub1_res0.4", resolution=0.4, restrict_to = ("leiden_res0.4", ["1"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub1_res0.5", resolution=0.4, restrict_to = ("leiden_res0.4", ["1"]))
# #sc.pl.umap(adata, color='leiden_res0.4_sub1_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.4_sub1_res0.5')
#
# #Subcluster 2 to get T-cells and separate endothelial cell types more
# brl.leiden(adata, key_added="leiden_res0.4_sub2_res0.1", resolution=0.1, restrict_to = ("leiden_res0.4", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub2_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub2_res0.3", resolution=0.3, restrict_to = ("leiden_res0.4", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub2_res0.4", resolution=0.4, restrict_to = ("leiden_res0.4", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub2_res0.5", resolution=0.5, restrict_to = ("leiden_res0.4", ["2"]))
#
# #Subcluster 2,3 further
# brl.leiden(adata, key_added="leiden_res0.4_sub2_res0.4_sub3_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4_sub2_res0.4", ["2,3"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub2_res0.4_sub3_res0.3", resolution=0.3, restrict_to = ("leiden_res0.4_sub2_res0.4", ["2,3"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub2_res0.4_sub3_res0.4", resolution=0.4, restrict_to = ("leiden_res0.4_sub2_res0.4", ["2,3"]))
# sc.pl.umap(adata, color="leiden_res0.4_sub2_res0.4_sub3_res0.2")
# sc.pl.umap(adata, color="leiden_res0.4_sub2_res0.4_sub3_res0.3")
# sc.pl.umap(adata, color="leiden_res0.4_sub2_res0.4_sub3_res0.4")
#
# #Subcluster 3 to get fibroblasts
# brl.leiden(adata, key_added="leiden_res0.4_sub3_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub3_res0.3", resolution=0.3, restrict_to = ("leiden_res0.4", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub3_res0.4", resolution=0.4, restrict_to = ("leiden_res0.4", ["3"]))
# #sc.pl.umap(adata, color='leiden_res0.4_sub3_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.4_sub3_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.4_sub3_res0.4')
#
# #Subcluster 4 for different types of endothelial cells
# brl.leiden(adata, key_added="leiden_res0.4_sub4_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4", ["4"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub4_res0.3", resolution=0.3, restrict_to = ("leiden_res0.4", ["4"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub4_res0.4", resolution=0.4, restrict_to = ("leiden_res0.4", ["4"]))
# #sc.pl.umap(adata, color='leiden_res0.4_sub4_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.4_sub4_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.4_sub4_res0.4')
#
# #Subcluster 5 to get immune and epithelial clusters out
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4", ["5"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.3", resolution=0.3, restrict_to = ("leiden_res0.4", ["5"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.4", resolution=0.4, restrict_to = ("leiden_res0.4", ["5"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.5", resolution=0.5, restrict_to = ("leiden_res0.5", ["5"]))
# #sc.pl.umap(adata, color='leiden_res0.4_sub5_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.4_sub5_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.4_sub5_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.4_sub5_res0.5')
#
# #Subcluster 5,1 further to get immune and epithelial clusters out
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.4_sub4_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4_sub5_res0.4", ["5,4"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.4_sub4_res0.3", resolution=0.3, restrict_to = ("leiden_res0.4_sub5_res0.4", ["5,4"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.4_sub4_res0.4", resolution=0.4, restrict_to = ("leiden_res0.4_sub5_res0.4", ["5,4"]))
# #sc.pl.umap(adata, color="leiden_res0.4_sub5_res0.4_sub4_res0.2")
# #sc.pl.umap(adata, color="leiden_res0.4_sub5_res0.4_sub4_res0.3")
# #sc.pl.umap(adata, color="leiden_res0.4_sub5_res0.4_sub4_res0.4")

# %% [raw]
# #Subclustering - "epithelial_lineage_split_nucnuc_RAPIDS_clustered_052824.rds"
# #Subcluster 1 to get PNECs split from other cell types
# brl.leiden(adata, key_added="leiden_res0.3_sub1_res0.1", resolution=0.1, restrict_to = ("leiden_res0.3", ["1"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub1_res0.13", resolution=0.13, restrict_to = ("leiden_res0.3", ["1"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub1_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3", ["1"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub1_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.3_sub1_res0.13')
# #sc.pl.umap(adata, color='leiden_res0.3_sub1_res0.2')
#
# #Subcluster 4 to examine low-quality cluster
# brl.leiden(adata, key_added="leiden_res0.3_sub4_res0.1", resolution=0.1, restrict_to = ("leiden_res0.3", ["4"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub4_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3", ["4"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub4_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3", ["4"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub4_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.3_sub4_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub4_res0.3')
#
# #Subcluster 7 to possibly split out mast cells
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.1", resolution=0.1, restrict_to = ("leiden_res0.3", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3", ["7"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.2')

# %% [raw]
# #Subclustering - "epithelial_airway_lineage_split_nucnuc_053024.rds"
# # Subcluster 0 to split epithelial cell types
# brl.leiden(adata, key_added="leiden_res0.4_sub0_res0.1", resolution=0.1, restrict_to = ("leiden_res0.4", ["0"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub0_res0.15", resolution=0.15, restrict_to = ("leiden_res0.4", ["0"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub0_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4", ["0"]))
# #sc.pl.umap(adata, color='leiden_res0.4_sub0_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.4_sub0_res0.15')
# #sc.pl.umap(adata, color='leiden_res0.4_sub0_res0.2')
#
# # Subcluster 5 to split epithelial cell types
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.15", resolution=0.15, restrict_to = ("leiden_res0.4", ["5"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4", ["5"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.25", resolution=0.25, restrict_to = ("leiden_res0.4", ["5"]))
# #sc.pl.umap(adata, color='leiden_res0.4_sub5_res0.15')
# #sc.pl.umap(adata, color='leiden_res0.4_sub5_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.4_sub5_res0.25')
#
# #Subcluster 5,0 further
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.2_sub0_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4_sub5_res0.2", ["5,0"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.2_sub0_res0.3", resolution=0.3, restrict_to = ("leiden_res0.4_sub5_res0.2", ["5,0"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.2_sub0_res0.4", resolution=0.4, restrict_to = ("leiden_res0.4_sub5_res0.2", ["5,0"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.2_sub0_res0.5", resolution=0.5, restrict_to = ("leiden_res0.4_sub5_res0.2", ["5,0"]))
# #sc.pl.umap(adata, color="leiden_res0.4_sub5_res0.2_sub0_res0.2")
# #sc.pl.umap(adata, color="leiden_res0.4_sub5_res0.2_sub0_res0.3")
# sc.pl.umap(adata, color="leiden_res0.4_sub5_res0.2_sub0_res0.4")
# sc.pl.umap(adata, color="leiden_res0.4_sub5_res0.2_sub0_res0.5")
#
# #Subcluster 5,0,2 further
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.2_sub0_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4_sub5_res0.2", ["5,0"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.2_sub0_res0.3", resolution=0.3, restrict_to = ("leiden_res0.4_sub5_res0.2", ["5,0"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.2_sub0_res0.4", resolution=0.4, restrict_to = ("leiden_res0.4_sub5_res0.2", ["5,0"]))
# #sc.pl.umap(adata, color="leiden_res0.4_sub5_res0.2_sub3_res0.2")
# #sc.pl.umap(adata, color="leiden_res0.4_sub5_res0.2_sub3_res0.3")
# #sc.pl.umap(adata, color="leiden_res0.4_sub5_res0.2_sub3_res0.4")
#
# #Subcluster 5,3 further
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.2_sub3_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4_sub5_res0.2", ["5,3"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.2_sub3_res0.3", resolution=0.3, restrict_to = ("leiden_res0.4_sub5_res0.2", ["5,3"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub5_res0.2_sub3_res0.4", resolution=0.4, restrict_to = ("leiden_res0.4_sub5_res0.2", ["5,3"]))
# #sc.pl.umap(adata, color="leiden_res0.4_sub5_res0.2_sub3_res0.2")
# #sc.pl.umap(adata, color="leiden_res0.4_sub5_res0.2_sub3_res0.3")
# #sc.pl.umap(adata, color="leiden_res0.4_sub5_res0.2_sub3_res0.4")
#
# # Subcluster 1 to get SCGB3A2+ vs. SCGB3A2+/SCGB1A1+
# brl.leiden(adata, key_added="leiden_res0.4_sub1_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4", ["1"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub1_res0.3", resolution=0.3, restrict_to = ("leiden_res0.4", ["1"]))
# #sc.pl.umap(adata, color='leiden_res0.4_sub1_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.4_sub1_res0.3')
#
# #Subcluster 1,0 further
# brl.leiden(adata, key_added="leiden_res0.4_sub1_res0.3_sub0_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4_sub1_res0.3", ["1,0"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub1_res0.3_sub0_res0.3", resolution=0.3, restrict_to = ("leiden_res0.4_sub1_res0.3", ["1,0"]))
# #sc.pl.umap(adata, color="leiden_res0.4_sub1_res0.3_sub0_res0.2")
# #sc.pl.umap(adata, color="leiden_res0.4_sub1_res0.3_sub0_res0.3")
#
# # Subcluster 6 to get PNECs
# brl.leiden(adata, key_added="leiden_res0.4_sub6_res0.1", resolution=0.1, restrict_to = ("leiden_res0.4", ["6"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub6_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4", ["6"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub6_res0.3", resolution=0.3, restrict_to = ("leiden_res0.4", ["6"]))
# #sc.pl.umap(adata, color='leiden_res0.4_sub6_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.4_sub6_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.4_sub6_res0.3')

# %% [raw]
# #Subclustering - "mesenchymal_lineage_split_nucnuc_RAPIDS_clustered_052824.rds"
# # Subcluster 7 to split adventitial, activated, peribronchial, and HAS1+ FBs
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.15", resolution=0.15, restrict_to = ("leiden_res0.3", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.4", resolution=0.4, restrict_to = ("leiden_res0.3", ["7"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.15')
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.4')
#
# # Subcluster 7,0 further to get activated FBs
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.4_sub0_res0.15", resolution=0.15, restrict_to = ("leiden_res0.3_sub7_res0.4", ["7,0"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.4_sub0_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3_sub7_res0.4", ["7,0"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.4_sub0_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3_sub7_res0.4", ["7,0"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.4_sub0_res0.4", resolution=0.4, restrict_to = ("leiden_res0.3_sub7_res0.4", ["7,0"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.4_sub0_res0.15')
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.4_sub0_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.4_sub0_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.4_sub0_res0.4')
#
# # Subcluster 7,2 further to split adventitial and HAS1+ FBs
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.4_sub2_res0.15", resolution=0.15, restrict_to = ("leiden_res0.3_sub7_res0.4", ["7,2"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.4_sub2_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3_sub7_res0.4", ["7,2"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.4_sub2_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3_sub7_res0.4", ["7,2"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.4_sub2_res0.4", resolution=0.4, restrict_to = ("leiden_res0.3_sub7_res0.4", ["7,2"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.4_sub2_res0.15')
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.4_sub2_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.4_sub2_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.4_sub2_res0.4')
#
# # Subcluster 4 to split SMCS/pericytes
# brl.leiden(adata, key_added="leiden_res0.3_sub4_res0.15", resolution=0.15, restrict_to = ("leiden_res0.3", ["4"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub4_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3", ["4"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub4_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3", ["4"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub4_res0.15')
# #sc.pl.umap(adata, color='leiden_res0.3_sub4_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub4_res0.3')
#
# # Subcluster 6 to split SMCs/pericytes and lipofibroblasts
# brl.leiden(adata, key_added="leiden_res0.3_sub6_res0.1", resolution=0.1, restrict_to = ("leiden_res0.3", ["6"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub6_res0.15", resolution=0.15, restrict_to = ("leiden_res0.3", ["6"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub6_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3", ["6"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub6_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3", ["6"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub6_res0.4", resolution=0.4, restrict_to = ("leiden_res0.3", ["6"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub6_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.3_sub6_res0.15')
# #sc.pl.umap(adata, color='leiden_res0.3_sub6_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub6_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.3_sub6_res0.4')
#
# # Split 6,0 further to get lipofibroblasts
# brl.leiden(adata, key_added="leiden_res0.3_sub6_res0.15_sub0_res0.15", resolution=0.15, restrict_to = ("leiden_res0.3_sub6_res0.15", ["6,0"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub6_res0.15_sub0_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3_sub6_res0.15", ["6,0"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub6_res0.15_sub0_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3_sub6_res0.15", ["6,0"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub6_res0.15_sub0_res0.4", resolution=0.4, restrict_to = ("leiden_res0.3_sub6_res0.15", ["6,0"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub6_res0.15_sub0_res0.15')
# #sc.pl.umap(adata, color='leiden_res0.3_sub6_res0.15_sub0_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub6_res0.15_sub0_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.3_sub6_res0.15_sub0_res0.4')
#
# # Subcluster 8 to split peribronchial and alveolar fibroblasts
# brl.leiden(adata, key_added="leiden_res0.3_sub8_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3", ["8"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub8_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3", ["8"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub8_res0.4", resolution=0.4, restrict_to = ("leiden_res0.3", ["8"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub8_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub8_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.3_sub8_res0.4')

# %% [raw]
# #Subclustering - "immune_lineage_split_nucnuc_RAPIDS_clustered_052824.rds"
# # Subcluster 7 to split out proliferating celltypes
# brl.leiden(adata, key_added="leiden_res0.4_sub7_res0.15", resolution=0.15, restrict_to = ("leiden_res0.4", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub7_res0.2", resolution=0.2, restrict_to = ("leiden_res0.4", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub7_res0.3", resolution=0.3, restrict_to = ("leiden_res0.4", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub7_res0.4", resolution=0.4, restrict_to = ("leiden_res0.4", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.4_sub7_res0.5", resolution=0.5, restrict_to = ("leiden_res0.4", ["7"]))
# sc.pl.umap(adata, color='leiden_res0.4_sub7_res0.15')
# sc.pl.umap(adata, color='leiden_res0.4_sub7_res0.2')
# sc.pl.umap(adata, color='leiden_res0.4_sub7_res0.3')
# sc.pl.umap(adata, color='leiden_res0.4_sub7_res0.4')
# sc.pl.umap(adata, color='leiden_res0.4_sub7_res0.5')

# %% [raw]
# #Subclustering - "immune_lymphoid_lineage_split_nucnuc_RAPIDS_clustered_060524.rds"
# # Subcluster 1 to split CD4+ T-cells and Tregs
# brl.leiden(adata, key_added="leiden_res0.3_sub1_res0.1", resolution=0.1, restrict_to = ("leiden_res0.3", ["1"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub1_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3", ["1"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub1_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3", ["1"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub1_res0.4", resolution=0.4, restrict_to = ("leiden_res0.3", ["1"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub1_res0.5", resolution=0.5, restrict_to = ("leiden_res0.3", ["1"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub1_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.3_sub1_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub1_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.3_sub1_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.3_sub1_res0.5')
#
# # Subcluster 2 to split proliferating cell types
# brl.leiden(adata, key_added="leiden_res0.3_sub2_res0.1", resolution=0.1, restrict_to = ("leiden_res0.3", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub2_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub2_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub2_res0.4", resolution=0.4, restrict_to = ("leiden_res0.3", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub2_res0.5", resolution=0.5, restrict_to = ("leiden_res0.3", ["2"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub2_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.3_sub2_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub2_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.3_sub2_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.3_sub2_res0.5')
#
# # Further subcluster 2,1 to split proliferating NK and T-cells
# brl.leiden(adata, key_added="leiden_res0.3_sub2_res0.2_sub1_res0.1", resolution=0.1, restrict_to = ("leiden_res0.3_sub2_res0.2", ["2,1"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub2_res0.2_sub1_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3_sub2_res0.2", ["2,1"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub2_res0.2_sub1_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3_sub2_res0.2", ["2,1"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub2_res0.2_sub1_res0.4", resolution=0.4, restrict_to = ("leiden_res0.3_sub2_res0.2", ["2,1"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub2_res0.2_sub1_res0.5", resolution=0.5, restrict_to = ("leiden_res0.3_sub2_res0.2", ["2,1"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub2_res0.2_sub1_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.3_sub2_res0.2_sub1_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub2_res0.2_sub1_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.3_sub2_res0.2_sub1_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.3_sub2_res0.2_sub1_res0.5')
#
# # Subcluster 3 to split CD4+ and CD8+ T-cells
# brl.leiden(adata, key_added="leiden_res0.3_sub3_res0.1", resolution=0.1, restrict_to = ("leiden_res0.3", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub3_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub3_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub3_res0.4", resolution=0.4, restrict_to = ("leiden_res0.3", ["3"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub3_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.3_sub3_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub3_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.3_sub3_res0.4')
#
# # Further subcluster 3,3 to get B cells out of T-cell cluster
# brl.leiden(adata, key_added="leiden_res0.3_sub3_res0.4_sub3_res0.1", resolution=0.1, restrict_to = ("leiden_res0.3_sub3_res0.4", ["3,3"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub3_res0.4_sub3_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3_sub3_res0.4", ["3,3"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub3_res0.4_sub3_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3_sub3_res0.4", ["3,3"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub3_res0.4_sub3_res0.4", resolution=0.4, restrict_to = ("leiden_res0.3_sub3_res0.4", ["3,3"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub3_res0.4_sub3_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.3_sub3_res0.4_sub3_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub3_res0.4_sub3_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.3_sub3_res0.4_sub3_res0.4')
#
# # Subcluster 7 to split B cells and plasma
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.1", resolution=0.1, restrict_to = ("leiden_res0.3", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.2", resolution=0.2, restrict_to = ("leiden_res0.3", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.3", resolution=0.3, restrict_to = ("leiden_res0.3", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.3_sub7_res0.4", resolution=0.4, restrict_to = ("leiden_res0.3", ["7"]))
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.3_sub7_res0.4')

# %% [raw]
# #Subclustering - "epithelial_alveolar_lineage_split_nucnuc_RAPIDS_clustered_060624.rds"
# # Subcluster 0 to split epithelial cell types
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.1", resolution=0.1, restrict_to = ("leiden_res0.5", ["0"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5", ["0"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5", ["0"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.4", resolution=0.4, restrict_to = ("leiden_res0.5", ["0"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.5", resolution=0.5, restrict_to = ("leiden_res0.5", ["0"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.5')
#
# # Subcluster 0,2 further
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.5_sub2_res0.1", resolution=0.1, restrict_to = ("leiden_res0.5_sub0_res0.5", ["0,2"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.5_sub2_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5_sub0_res0.5", ["0,2"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.5_sub2_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5_sub0_res0.5", ["0,2"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.5_sub2_res0.4", resolution=0.4, restrict_to = ("leiden_res0.5_sub0_res0.5", ["0,2"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.5_sub2_res0.5", resolution=0.5, restrict_to = ("leiden_res0.5_sub0_res0.5", ["0,2"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.5_sub2_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.5_sub2_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.5_sub2_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.5_sub2_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.5_sub2_res0.5')
#
# # Subcluster 0,7 further
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.5_sub7_res0.1", resolution=0.1, restrict_to = ("leiden_res0.5_sub0_res0.5", ["0,7"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.5_sub7_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5_sub0_res0.5", ["0,7"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.5_sub7_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5_sub0_res0.5", ["0,7"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.5_sub7_res0.4", resolution=0.4, restrict_to = ("leiden_res0.5_sub0_res0.5", ["0,7"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub0_res0.5_sub7_res0.5", resolution=0.5, restrict_to = ("leiden_res0.5_sub0_res0.5", ["0,7"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.5_sub7_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.5_sub7_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.5_sub7_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.5_sub7_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.5_sub0_res0.5_sub7_res0.5')
#
# # Subcluster 2 to split proliferating cell types
# brl.leiden(adata, key_added="leiden_res0.5_sub2_res0.1", resolution=0.1, restrict_to = ("leiden_res0.5", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub2_res0.15", resolution=0.15, restrict_to = ("leiden_res0.5", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub2_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub2_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub2_res0.4", resolution=0.4, restrict_to = ("leiden_res0.5", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub2_res0.5", resolution=0.5, restrict_to = ("leiden_res0.5", ["2"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub2_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.5_sub2_res0.15')
# #sc.pl.umap(adata, color='leiden_res0.5_sub2_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub2_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.5_sub2_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.5_sub2_res0.5')
#
# # Subcluster 2,9 further (airway cell types)
# brl.leiden(adata, key_added="leiden_res0.5_sub2_res0.5_sub9_res0.1", resolution=0.1, restrict_to = ("leiden_res0.5_sub2_res0.5", ["2,9"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub2_res0.5_sub9_res0.15", resolution=0.15, restrict_to = ("leiden_res0.5_sub2_res0.5", ["2,9"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub2_res0.5_sub9_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5_sub2_res0.5", ["2,9"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub2_res0.5_sub9_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5_sub2_res0.5", ["2,9"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub2_res0.5_sub9_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.5_sub2_res0.5_sub9_res0.15')
# #sc.pl.umap(adata, color='leiden_res0.5_sub2_res0.5_sub9_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub2_res0.5_sub9_res0.3')
#
# # Subcluster 3 to split out KRT5-/KRT17+ cells
# brl.leiden(adata, key_added="leiden_res0.5_sub3_res0.1", resolution=0.1, restrict_to = ("leiden_res0.5", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub3_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub3_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub3_res0.4", resolution=0.4, restrict_to = ("leiden_res0.5", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub3_res0.5", resolution=0.5, restrict_to = ("leiden_res0.5", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub3_res0.6", resolution=0.6, restrict_to = ("leiden_res0.5", ["3"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub3_res0.7", resolution=0.7, restrict_to = ("leiden_res0.5", ["3"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub3_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.5_sub3_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub3_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.5_sub3_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.5_sub3_res0.5')
# #sc.pl.umap(adata, color='leiden_res0.5_sub3_res0.6')
# #sc.pl.umap(adata, color='leiden_res0.5_sub3_res0.7')
#
# # Subcluster 5 for immune contamination
# brl.leiden(adata, key_added="leiden_res0.5_sub5_res0.1", resolution=0.1, restrict_to = ("leiden_res0.5", ["5"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub5_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5", ["5"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub5_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5", ["5"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub5_res0.4", resolution=0.4, restrict_to = ("leiden_res0.5", ["5"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub5_res0.5", resolution=0.5, restrict_to = ("leiden_res0.5", ["5"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub5_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.5_sub5_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub5_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.5_sub5_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.5_sub5_res0.5')
#
# # Subcluster 6 for mesenchymal contamination
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.1", resolution=0.1, restrict_to = ("leiden_res0.5", ["6"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5", ["6"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5", ["6"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.4", resolution=0.4, restrict_to = ("leiden_res0.5", ["6"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.4')
#
# # Subcluster 6,0 further
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3_sub0_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5_sub6_res0.3", ["6,0"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3_sub0_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5_sub6_res0.3", ["6,0"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3_sub0_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3_sub0_res0.3')
#
# # Subcluster 6,1 further
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3_sub1_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5_sub6_res0.3", ["6,1"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3_sub1_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5_sub6_res0.3", ["6,1"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3_sub1_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3_sub1_res0.3')
#
# # Subcluster 6,2 further
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3_sub2_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5_sub6_res0.3", ["6,2"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3_sub2_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5_sub6_res0.3", ["6,2"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3_sub2_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3_sub2_res0.3')
#
# # Subcluster 6,3 further
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3_sub3_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5_sub6_res0.3", ["6,3"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3_sub3_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5_sub6_res0.3", ["6,3"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3_sub3_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3_sub3_res0.3')
#
# # Subcluster 6,4 further
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3_sub4_res0.1", resolution=0.1, restrict_to = ("leiden_res0.5_sub6_res0.3", ["6,4"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3_sub4_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5_sub6_res0.3", ["6,4"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3_sub4_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5_sub6_res0.3", ["6,4"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3_sub4_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3_sub4_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3_sub4_res0.3')
#
# # Subcluster 6,5 further
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3_sub5_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5_sub6_res0.3", ["6,5"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub6_res0.3_sub5_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5_sub6_res0.3", ["6,5"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3_sub5_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub6_res0.3_sub5_res0.3')
#
# # Subcluster 7 for AT1 vs. Transitional AT2
# brl.leiden(adata, key_added="leiden_res0.5_sub7_res0.13", resolution=0.13, restrict_to = ("leiden_res0.5", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub7_res0.15", resolution=0.15, restrict_to = ("leiden_res0.5", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub7_res0.2", resolution=0.2, restrict_to = ("leiden_res0.5", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub7_res0.3", resolution=0.3, restrict_to = ("leiden_res0.5", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub7_res0.35", resolution=0.35, restrict_to = ("leiden_res0.5", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.5_sub7_res0.4", resolution=0.4, restrict_to = ("leiden_res0.5", ["7"]))
# #sc.pl.umap(adata, color='leiden_res0.5_sub7_res0.13')
# #sc.pl.umap(adata, color='leiden_res0.5_sub7_res0.15')
# #sc.pl.umap(adata, color='leiden_res0.5_sub7_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.5_sub7_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.5_sub7_res0.35')
# #sc.pl.umap(adata, color='leiden_res0.5_sub7_res0.4')

# %% [raw]
# #Subclustering - "immune_myeloid_lineage_split_nucnuc_RAPIDS_clustered_060524.rds"
# # Subcluster 4 to split cDC2s
# brl.leiden(adata, key_added="leiden_res0.8_sub4_res0.1", resolution=0.1, restrict_to = ("leiden_res0.8", ["4"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub4_res0.15", resolution=0.15, restrict_to = ("leiden_res0.8", ["4"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub4_res0.2", resolution=0.2, restrict_to = ("leiden_res0.8", ["4"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub4_res0.3", resolution=0.3, restrict_to = ("leiden_res0.8", ["4"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub4_res0.4", resolution=0.4, restrict_to = ("leiden_res0.8", ["4"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub4_res0.5", resolution=0.5, restrict_to = ("leiden_res0.8", ["4"]))
# #sc.pl.umap(adata, color='leiden_res0.8_sub4_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.8_sub4_res0.15')
# #sc.pl.umap(adata, color='leiden_res0.8_sub4_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.8_sub4_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.8_sub4_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.8_sub4_res0.5')
#
# # Further subcluster 4,0
# brl.leiden(adata, key_added="leiden_res0.8_sub4_res0.1_sub0_res0.1", resolution=0.1, restrict_to = ("leiden_res0.8_sub4_res0.1", ["4,0"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub4_res0.1_sub0_res0.15", resolution=0.15, restrict_to = ("leiden_res0.8_sub4_res0.1", ["4,0"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub4_res0.1_sub0_res0.2", resolution=0.2, restrict_to = ("leiden_res0.8_sub4_res0.1", ["4,0"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub4_res0.1_sub0_res0.3", resolution=0.3, restrict_to = ("leiden_res0.8_sub4_res0.1", ["4,0"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub4_res0.1_sub0_res0.4", resolution=0.4, restrict_to = ("leiden_res0.8_sub4_res0.1", ["4,0"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub4_res0.1_sub0_res0.5", resolution=0.5, restrict_to = ("leiden_res0.8_sub4_res0.1", ["4,0"]))
# #sc.pl.umap(adata, color='leiden_res0.8_sub4_res0.1_sub0_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.8_sub4_res0.1_sub0_res0.15')
# #sc.pl.umap(adata, color='leiden_res0.8_sub4_res0.1_sub0_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.8_sub4_res0.1_sub0_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.8_sub4_res0.1_sub0_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.8_sub4_res0.1_sub0_res0.5')
#
# # Subcluster 10 to split FCN1+ population
# brl.leiden(adata, key_added="leiden_res0.8_sub10_res0.1", resolution=0.1, restrict_to = ("leiden_res0.8", ["10"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub10_res0.2", resolution=0.2, restrict_to = ("leiden_res0.8", ["10"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub10_res0.3", resolution=0.3, restrict_to = ("leiden_res0.8", ["10"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub10_res0.4", resolution=0.4, restrict_to = ("leiden_res0.8", ["10"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub10_res0.5", resolution=0.5, restrict_to = ("leiden_res0.8", ["10"]))
# #sc.pl.umap(adata, color='leiden_res0.8_sub10_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.8_sub10_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.8_sub10_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.8_sub10_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.8_sub10_res0.5')
#
# # Subcluster 14 to split T-cells and NK cells
# brl.leiden(adata, key_added="leiden_res0.8_sub14_res0.1", resolution=0.1, restrict_to = ("leiden_res0.8", ["14"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub14_res0.2", resolution=0.2, restrict_to = ("leiden_res0.8", ["14"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub14_res0.3", resolution=0.3, restrict_to = ("leiden_res0.8", ["14"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub14_res0.4", resolution=0.4, restrict_to = ("leiden_res0.8", ["14"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub14_res0.5", resolution=0.5, restrict_to = ("leiden_res0.8", ["14"]))
# #sc.pl.umap(adata, color='leiden_res0.8_sub14_res0.1')
# #sc.pl.umap(adata, color='leiden_res0.8_sub14_res0.2')
# #sc.pl.umap(adata, color='leiden_res0.8_sub14_res0.3')
# #sc.pl.umap(adata, color='leiden_res0.8_sub14_res0.4')
# #sc.pl.umap(adata, color='leiden_res0.8_sub14_res0.5')
#
# ## Subcluster all clusters without clear separation into FCN1+, S100A+, SPP1+, or FABP4+
# # Subcluster 2
# brl.leiden(adata, key_added="leiden_res0.8_sub2_res0.1", resolution=0.1, restrict_to = ("leiden_res0.8", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub2_res0.2", resolution=0.2, restrict_to = ("leiden_res0.8", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub2_res0.3", resolution=0.3, restrict_to = ("leiden_res0.8", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub2_res0.4", resolution=0.4, restrict_to = ("leiden_res0.8", ["2"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub2_res0.5", resolution=0.5, restrict_to = ("leiden_res0.8", ["2"]))
# # Subcluster 6
# brl.leiden(adata, key_added="leiden_res0.8_sub6_res0.1", resolution=0.1, restrict_to = ("leiden_res0.8", ["6"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub6_res0.2", resolution=0.2, restrict_to = ("leiden_res0.8", ["6"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub6_res0.3", resolution=0.3, restrict_to = ("leiden_res0.8", ["6"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub6_res0.4", resolution=0.4, restrict_to = ("leiden_res0.8", ["6"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub6_res0.5", resolution=0.5, restrict_to = ("leiden_res0.8", ["6"]))
# # Subcluster 7
# brl.leiden(adata, key_added="leiden_res0.8_sub7_res0.1", resolution=0.1, restrict_to = ("leiden_res0.8", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub7_res0.2", resolution=0.2, restrict_to = ("leiden_res0.8", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub7_res0.3", resolution=0.3, restrict_to = ("leiden_res0.8", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub7_res0.4", resolution=0.4, restrict_to = ("leiden_res0.8", ["7"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub7_res0.5", resolution=0.5, restrict_to = ("leiden_res0.8", ["7"]))
# # Subcluster 9
# brl.leiden(adata, key_added="leiden_res0.8_sub9_res0.1", resolution=0.1, restrict_to = ("leiden_res0.8", ["9"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub9_res0.2", resolution=0.2, restrict_to = ("leiden_res0.8", ["9"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub9_res0.3", resolution=0.3, restrict_to = ("leiden_res0.8", ["9"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub9_res0.4", resolution=0.4, restrict_to = ("leiden_res0.8", ["9"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub9_res0.5", resolution=0.5, restrict_to = ("leiden_res0.8", ["9"]))
# # Subcluster 15
# brl.leiden(adata, key_added="leiden_res0.8_sub15_res0.1", resolution=0.1, restrict_to = ("leiden_res0.8", ["15"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub15_res0.2", resolution=0.2, restrict_to = ("leiden_res0.8", ["15"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub15_res0.3", resolution=0.3, restrict_to = ("leiden_res0.8", ["15"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub15_res0.4", resolution=0.4, restrict_to = ("leiden_res0.8", ["15"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub15_res0.5", resolution=0.5, restrict_to = ("leiden_res0.8", ["15"]))
# # Subcluster 16
# brl.leiden(adata, key_added="leiden_res0.8_sub16_res0.1", resolution=0.1, restrict_to = ("leiden_res0.8", ["16"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub16_res0.2", resolution=0.2, restrict_to = ("leiden_res0.8", ["16"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub16_res0.3", resolution=0.3, restrict_to = ("leiden_res0.8", ["16"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub16_res0.4", resolution=0.4, restrict_to = ("leiden_res0.8", ["16"]))
# brl.leiden(adata, key_added="leiden_res0.8_sub16_res0.5", resolution=0.5, restrict_to = ("leiden_res0.8", ["16"]))

# %%
adata.X = sc.pp.log1p(adata.raw.X, copy=True)

# %%
#Cast int32 variables to float64 so that the object can be converted back to Seurat. Note that int64 may work as well, but I haven't tested it.
adata.obs["nCount_RNA"] = adata.obs["nCount_RNA"].astype('float64')
adata.obs["nFeature_RNA"] = adata.obs["nFeature_RNA"].astype('float64')
adata.obs["x_centroid"] = adata.obs["x_centroid"].astype('float64')
adata.obs["y_centroid"] = adata.obs["y_centroid"].astype('float64')
adata.obs["transcript_counts"] = adata.obs["transcript_counts"].astype('float64')
adata.obs["control_probe_counts"] = adata.obs["control_probe_counts"].astype('float64')
adata.obs["control_codeword_counts"] = adata.obs["control_codeword_counts"].astype('float64')
adata.obs["unassigned_codeword_counts"] = adata.obs["unassigned_codeword_counts"].astype('float64')
adata.obs["deprecated_codeword_counts"] = adata.obs["deprecated_codeword_counts"].astype('float64')
adata.obs["total_counts"] = adata.obs["total_counts"].astype('float64')
adata.obs["cell_area"] = adata.obs["cell_area"].astype('float64')
adata.obs["nucleus_area"] = adata.obs["nucleus_area"].astype('float64')
adata.obs["num.negcontrolprobe"] = adata.obs["num.negcontrolprobe"].astype('float64')
adata.obs["num.negcontrolcodeword"] = adata.obs["num.negcontrolcodeword"].astype('float64')
adata.obs["num.unassigned"] = adata.obs["num.unassigned"].astype('float64')
adata.obs["perc_negcontrolprobe"] = adata.obs["perc_negcontrolprobe"].astype('float64')
adata.obs["perc_negcontrolcodeword"] = adata.obs["perc_negcontrolcodeword"].astype('float64')
adata.obs["perc_unassigned"] = adata.obs["perc_unassigned"].astype('float64')
adata.obs["adj_x_centroid"] = adata.obs["adj_x_centroid"].astype('float64')
adata.obs["adj_y_centroid"] = adata.obs["adj_y_centroid"].astype('float64')
adata.obs["perc_negcontrolorunassigned"] = adata.obs["perc_negcontrolorunassigned"].astype('float64')

# %%
#Write anndata to h5 file to import into R for conversion to Seurat object. Next move to commandline R for sceasy.
adata.write_h5ad(filename=new_adata_path)

# %%
adata.raw.X
# Out:
# array([[ 0.,  0.,  2., ...,  2.,  0.,  0.],
#        [ 0.,  0.,  4., ...,  4.,  2.,  0.],
#        [ 0.,  0.,  0., ...,  1.,  2.,  0.],
#        ...,
#        [ 0.,  0.,  1., ..., 15.,  1.,  0.],
#        [ 0.,  0.,  0., ...,  2.,  0.,  0.],
#        [ 0.,  0.,  0., ...,  4.,  3.,  0.]], dtype=float32)

# %%
clustered_metadata = adata.obs
metadata = pd.DataFrame.to_csv(clustered_metadata, new_metadata_path)

# %%
clustered_metadata
# Out:
#                                          X.4                    X.1  \
# TILD315LF_acbgonlh-1    TILD315LF_acbgonlh-1   TILD315LF_acbgonlh-1
# TILD315LF_adcpicbp-1    TILD315LF_adcpicbp-1   TILD315LF_adcpicbp-1
# TILD315LF_adkillbg-1    TILD315LF_adkillbg-1   TILD315LF_adkillbg-1
# TILD315LF_adkimjlp-1    TILD315LF_adkimjlp-1   TILD315LF_adkimjlp-1
# TILD315LF_aeepcgol-1    TILD315LF_aeepcgol-1   TILD315LF_aeepcgol-1
# ...                                      ...                    ...
# VUILD105LF_aaabcfbb-1  VUILD105LF_aaabcfbb-1  VUILD105LF_aaabcfbb-1
# VUILD105LF_aaabcfda-1  VUILD105LF_aaabcfda-1  VUILD105LF_aaabcfda-1
# VUILD105LF_aaabdpnm-1  VUILD105LF_aaabdpnm-1  VUILD105LF_aaabdpnm-1
# VUILD105LF_aaabfbbe-1  VUILD105LF_aaabfbbe-1  VUILD105LF_aaabfbbe-1
# VUILD105LF_aaabfbdo-1  VUILD105LF_aaabfbdo-1  VUILD105LF_aaabfbdo-1
#
#                                            X     orig.ident  nCount_RNA  \
# TILD315LF_acbgonlh-1       sample_acbgonlh-1  SeuratProject        95.0
# ...
